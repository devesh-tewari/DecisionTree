# %%
import pandas
import numpy
from numpy import log2 as log
import pprint
import matplotlib.pyplot as plt

#csv_path = raw_input("Enter path to input CSV file: ")
dataset = pandas.read_csv('decision_Tree/train.csv')
#data.keys()[:-1]
#sub=data[data['salary'] == 'low']
#clValue,counts = numpy.unique(sub['left'],return_counts=True)
#print clValue, counts
#dataset.head()
#dataset.keys()[[5,7,8,9]]
#print p, type(p)
#len(data.index)

# from sklearn.model_selection import train_test_split

# data, validation_data = train_test_split(dataset, test_size=0.2)

splitted = numpy.split(dataset, [int(.8 * len(dataset.index))])
data = splitted[0].reset_index()
validation_data = splitted[1].reset_index()

# print validation_data['left'].value_counts(1)
#len(data[data['number_project'] == 7])
#len(data.index)
#data[(data['Work_accident'] == 0) & (data['salary'] == 'low') & (data['sales'] == 'IT')] #& (data['promotion_last_5years'] == 1)]

# %%
X = dataset.keys()[[0,1,2,3,4,5,7,8,9]]
Y = 'left'

# %%
vi = dataset.keys()[0]
filtered = dataset[(dataset[vi] >= 0) & (dataset[vi] < 380)]
yy = filtered[Y]
xx = filtered[vi]
#plt.scatter(xx, yy)
#plt.show()

filtered[filtered[Y] == 0]

x1 ,y1 = numpy.unique(filtered[filtered[Y] == 0][vi], return_counts=True)
x2 ,y2 = numpy.unique(filtered[filtered[Y] == 1][vi], return_counts=True)

plt.scatter(x1, y1, color='green')
plt.scatter(x2, y2, color='red')
plt.show()

#df['salary'].value_counts().plot()

# %%
# def Range_set(att):
#     #print att
#     if att == 'satisfaction_level':
#         return [[0,0.0,0.12],[1,0.12,0.36],[2,0.36,0.47],[3,0.47,0.92],[4,0.92,1.1]]
    
#     if att == 'last_evaluation':
#         return [[0,0.0,0.45],[1,0.45,0.58],[2,0.58,0.77],[3,0.77,1.1]]
        
#     if att == 'number_project':
#         return [[0,0,3],[1,3,6],[2,6,100]]
    
#     if att == 'average_montly_hours':
#         return [[0,0,127],[1,127,162],[2,162,217],[3,217,288],[4,288,1000]]
    
#     if att == 'time_spend_company':
#         return [[0,0,3],[1,3,4],[2,4,5],[3,5,7],[4,7,100]]
    
def Range_set(att, data, measure = 'entropy'):
    #print att
    notLeft_count = len(data[data[Y] == 0])
    left_count = len(data[data[Y] == 1])
    impurity = 0.0
    
    q = float(left_count) / (left_count + notLeft_count)
    if measure == 'entropy':
        impurity = - ( q*log(q) + (1-q)*log(1-q) )
    elif measure == 'gini':
        impurity = 4 * q * (1-q)
    elif measure == 'misclassification':
        impurity = 2 * min(q, 1-q)
            
    attValue = numpy.unique(data[att])
    attValue.sort()
    max_info_gain = 0.0
    max_at = attValue[0] + 0.0005
    i = 0
    while i < len(attValue) - 1:
        impurity_split = 0.0
        
        mid = float( attValue[i] + attValue[i+1] ) / 2
        i += 1
        left_data = data[data[att] < mid]
        right_data = data[data[att] >= mid]
        
        notLeft_count_split = len(left_data[left_data[Y] == 0])
        left_count_split = len(left_data[left_data[Y] == 1])

        if left_count_split == 0 or notLeft_count_split == 0:
            #in this case entropy_split_val = 0
            continue
        else:
            q = float(left_count_split) / (left_count_split + notLeft_count_split)

        if measure == 'entropy':
            impurity_split_val = - ( q*log(q) + (1-q)*log(1-q) )
        elif measure == 'gini':
            impurity_split_val = 4 * q * (1-q) #scaled to [0,1]
        elif measure == 'misclassification':
            impurity_split_val = 2 * min(q, 1-q) #scaled to [0,1]

        weight = float( len(left_data.index) ) / len(data.index)

        impurity_split += weight * impurity_split_val
        
        
        notLeft_count_split = len(right_data[right_data[Y] == 0])
        left_count_split = len(right_data[right_data[Y] == 1])

        if left_count_split == 0 or notLeft_count_split == 0:
            #in this case entropy_split_val = 0
            continue
        else:
            q = float(left_count_split) / (left_count_split + notLeft_count_split)

        if measure == 'entropy':
            impurity_split_val = - ( q*log(q) + (1-q)*log(1-q) )
        elif measure == 'gini':
            impurity_split_val = 4 * q * (1-q) #scaled to [0,1]
        elif measure == 'misclassification':
            impurity_split_val = 2 * min(q, 1-q) #scaled to [0,1]

        weight = float( len(right_data.index) ) / len(data.index)

        impurity_split += weight * impurity_split_val
        
        info_gain = impurity - impurity_split
        if info_gain > max_info_gain:
            max_info_gain = info_gain
            max_at = mid
            #print max_at
            
    #print attValue, max_at
    return [ str(attValue[0]) + '~' + str(max_at),  str(max_at) + '~' + str(attValue[len(attValue)-1]) ]

                                                                          
def is_categorical(att):
    if att in dataset.keys()[[5,6,7,8,9]]:
        return True
    else:
        return False


def choose_best_attribute(data, x, measure='entropy'):
    Ranges = []
    ranges = []
    if len(x) == 1:
        return x[0], Ranges
    
    notLeft_count = len(data[data[Y] == 0])
    left_count = len(data[data[Y] == 1])
    impurity = 0.0
    if left_count == 0 or notLeft_count == 0:
        #in this case entropy_val = 0
        return 'noBest', Ranges
    else:
        q = float(left_count) / (left_count + notLeft_count)
        if measure == 'entropy':
            impurity = - ( q*log(q) + (1-q)*log(1-q) )
        elif measure == 'gini':
            impurity = 4 * q * (1-q)
        elif measure == 'misclassification':
            impurity = 2 * min(q, 1-q)

    max_info_gain = float(-99999999999)
    
    for att in x:
        impurity_split = 0.0
        
        if is_categorical(att):
            attValue = numpy.unique(data[att])
            for value in attValue:
                subdata = data[data[att] == value]
                notLeft_count_split = len(subdata[subdata[Y] == 0])
                left_count_split = len(subdata[subdata[Y] == 1])
                
                if left_count_split == 0 or notLeft_count_split == 0:
                    #in this case entropy_split_val = 0
                    continue
                else:
                    q = float(left_count_split) / (left_count_split + notLeft_count_split)
    
                if measure == 'entropy':
                    impurity_split_val = - ( q*log(q) + (1-q)*log(1-q) )
                elif measure == 'gini':
                    impurity_split_val = 4 * q * (1-q)
                elif measure == 'misclassification':
                    impurity_split_val = 2 * min(q, 1-q)
                    
                weight = float( len(subdata.index) ) / len(data.index)
            
                impurity_split += weight * impurity_split_val
        
        else:
            ranges = Range_set(att, data)
            Range = ranges[0].split('~')
            subdata = data[(data[att] >= float(Range[0])) & (data[att] < float(Range[1]))]
            notLeft_count_split = len(subdata[subdata[Y] == 0])
            left_count_split = len(subdata[subdata[Y] == 1])

            if left_count_split == 0 or notLeft_count_split == 0:
                #in this case entropy_split_val = 0
                continue
            else:
                q = float(left_count_split) / (left_count_split + notLeft_count_split)

            if measure == 'entropy':
                impurity_split_val = - ( q*log(q) + (1-q)*log(1-q) )
            elif measure == 'gini':
                impurity_split_val = 4 * q * (1-q) #scaled to [0,1]
            elif measure == 'misclassification':
                impurity_split_val = 2 * min(q, 1-q) #scaled to [0,1]

            weight = float( len(subdata.index) ) / len(data.index)

            impurity_split += weight * impurity_split_val

            Range = ranges[1].split('~')
            subdata = data[(data[att] >= float(Range[0])) & (data[att] <= float(Range[1]))]
            notLeft_count_split = len(subdata[subdata[Y] == 0])
            left_count_split = len(subdata[subdata[Y] == 1])

            if left_count_split == 0 or notLeft_count_split == 0:
                #in this case entropy_split_val = 0
                continue
            else:
                q = float(left_count_split) / (left_count_split + notLeft_count_split)

            if measure == 'entropy':
                impurity_split_val = - ( q*log(q) + (1-q)*log(1-q) )
            elif measure == 'gini':
                impurity_split_val = 4 * q * (1-q) #scaled to [0,1]
            elif measure == 'misclassification':
                impurity_split_val = 2 * min(q, 1-q) #scaled to [0,1]

            weight = float( len(subdata.index) ) / len(data.index)

            impurity_split += weight * impurity_split_val
            
        #print entropy_split, att
        info_gain = impurity - impurity_split
        #print "ingogain", info_gain
        #print info_gain, att
        if info_gain > max_info_gain:
            max_info_gain = info_gain
            bestAtt = att
            Ranges = ranges
    
    #print ""
    
    if max_info_gain <= 0.001:
        return 'noBest', Ranges
    
    #print ""
    #print max_info_gain, bestAtt
    #print ""
    return bestAtt, Ranges


def check_purity(y, measure = 'entropy'):
    left_count = 0
    notLeft_count = 0
    
    for value in y:
        if value == 1:
            left_count = left_count + 1
        else:
            notLeft_count = notLeft_count + 1
            
    if left_count + notLeft_count < 5:
        if left_count > notLeft_count:
            return 1, 1
        else:
            return 1, 0

    elif left_count == 0:
        return 1, 0
    elif notLeft_count == 0:
        return 1, 1
    
    impurity = 0.0
    q = float(left_count) / (left_count + notLeft_count)
    
    if measure == 'entropy':
        impurity = - ( q*log(q) + (1-q)*log(1-q) )
    if measure == 'gini':
        impurity = 4 * q * (1-q)
    if measure == 'misclassification':
        impurity = 2 * min(q, 1-q)
        
    purity = 1 - impurity
    #print purity
    
    if left_count > notLeft_count:
        return purity, 1
    
    else:
        return purity, 0

# %%
def build_decision_tree(data, x, measure = 'entropy', tree = None): 
    
    #if pure enough
    purity, majority = check_purity(data[Y], measure)
    
    if measure == 'entropy' and purity > 0.65:
        return majority
    if measure == 'gini' and purity > 0.75:
        return majority
    if measure == 'misclassification' and purity > 0.85:
        return majority

    #get an attribute with maximum information gain
    bestAtt, Range_str = choose_best_attribute(data, x, measure)
    if bestAtt == 'noBest':
        return majority
    
    if tree == None:                    
        tree = {}
        tree[bestAtt] = {}
    
    if is_categorical(bestAtt):
        #for all categorical values keep growing tree
        attValue = numpy.unique(dataset[bestAtt])
        for value in attValue:
            subdata = data[data[bestAtt] == value]
            #if len(x) == 1:
            #   tree[bestAtt][value] = majority
            #else:
            tree[bestAtt][value] = build_decision_tree(subdata, x.drop(bestAtt), measure) #Calling the function recursively 
    
    else:
        #divide the numerical data in specified range(s)
        #print Range_set(bestAtt)
        Range = Range_str[0].split('~')
        subdata = data[(data[bestAtt] >= float(Range[0])) & (data[bestAtt] < float(Range[1]))]
        #if len(x) == 1:
        #    tree[bestAtt][Range[0]] = majority
        #else:
        tree[bestAtt][Range_str[0]] = build_decision_tree(subdata, x, measure)
        
        Range = Range_str[1].split('~')
        subdata = data[(data[bestAtt] >= float(Range[0])) & (data[bestAtt] <= float(Range[1]))]
        tree[bestAtt][Range_str[1]] = build_decision_tree(subdata, x, measure)
            
    return tree
    
#print type(X)
decision_tree = build_decision_tree(data, X)
pprint.pprint(decision_tree)
# Out:
# {'satisfaction_level': {'0.09~0.465': {'number_project': {'2.5~7': {'average_montly_hours': {'242.5~310': {'number_project': {'3~5.5': {'average_montly_hours': {'243~286.5': {'sales': {'IT': {'Work_accident': {0: {'salary': {'high': 0,
#                                                                                                                                                                                                                                  'low': 0,
#                                                                                                                                                                                                                                  'medium': 0}},
#                                                                                                                                                                                                                   1: 0}},
#                                                                                                                                                                                          'RandD': {'last_evaluation': {'0.47~0.82': {'Work_accident': {0: 0,
#                                                                                                                                                                                                                                                        1: 0}},
#                                                                                                                                                                                                                        '0.82~1.0': {'salary': {'high': 1,
#                                                                                                                                                                                                                                                'low': 0,
#                                                                                                                                                                                                                                                'medium': 1}}}},
#                                                                                                                                                                                          'accounting': {'salary': {'high': 0,
#                                                                                                                                                                                                                    'low': 0,
#                                                                                                                                                                                                                    'medium': 0}},
#                                                                                                                                                                                          'hr': {'Work_accident': {0: 0,
#                                                                                                                                                                                                                   1: 0}},
#                                                                                                                                                                                          'management': 0,
#                                                                                                                                                                                          'marketing': 0,
#                                                                                                                                                                                          'product_mng': 0,
#                                                                                                                                                                                          'sales': {'salary': {'high': 0,
#                                                                                                                                                                                                               'low': {'last_evaluation': {'0.49~0.865': {'Work_accident': {0: 0,
#                                                                                                                                                                                                                                                                            1: 0}},
#                                                                                                                                                                                                                                           '0.865~0.96': {'Work_accident': {0: 0,
#                                                                                                                                                                                                                                                                            1: 0}}}},
#                                                                                                                                                                                                               'medium': 0}},
#                                                                                                                                                                                          'support': {'salary': {'high': 0,
#                                                                                                                                                                                                                 'low': {'last_evaluation': {'0.38~0.8': {'Work_accident': {0: 0,
#                                                                                                                                                                                                                                                                            1: 0}},
#                                                                                                                                                                                                                                             '0.8~0.9': 0}},
#                                                                                                                                                                                                                 'medium': 0}},
#                                                                                                                                                                                          'technical': 0}},
#                                                                                                                                                                  '286.5~310': {'sales': {'IT': 1,
#                                                                                                                                                                                          'RandD': 0,
#                                                                                                                                                                                          'accounting': 1,
#                                                                                                                                                                                          'hr': 0,
#                                                                                                                                                                                          'management': 0,
#                                                                                                                                                                                          'marketing': 1,
#                                                                                                                                                                                          'product_mng': 1,
#                                                                                                                                                                                          'sales': 1,
#                                                                                                                                                                                          'support': 1,
#                                                                                                                                                                                          'technical': 0}}}},
#                                                                                                                               '5.5~7': {'last_evaluation': {'0.37~0.76': {'sales': {'IT': 0,
#                                                                                                                                                                                     'RandD': 0,
#                                                                                                                                                                                     'accounting': 0,
#                                                                                                                                                                                     'hr': 0,
#                                                                                                                                                                                     'management': 0,
#                                                                                                                                                                                     'marketing': 0,
#                                                                                                                                                                                     'product_mng': 0,
#                                                                                                                                                                                     'sales': {'salary': {'high': 0,
#                                                                                                                                                                                                          'low': 0,
#                                                                                                                                                                                                          'medium': {'promotion_last_5years': {0: {'average_montly_hours': {'250~276.0': 0,
#                                                                                                                                                                                                                                                                            '276.0~283': 0}},
#                                                                                                                                                                                                                                               1: 0}}}},
#                                                                                                                                                                                     'support': 0,
#                                                                                                                                                                                     'technical': 0}},
#                                                                                                                                                             '0.76~1.0': 1}}}},
#                                                                                              '96~242.5': {'sales': {'IT': 0,
#                                                                                                                     'RandD': 0,
#                                                                                                                     'accounting': {'number_project': {'3~5.5': {'last_evaluation': {'0.37~0.97': 0,
#                                                                                                                                                                                     '0.97~1.0': 1}},
#                                                                                                                                                       '5.5~7': {'Work_accident': {0: {'last_evaluation': {'0.38~0.455': 0,
#                                                                                                                                                                                                           '0.455~0.76': {'salary': {'high': 0,
#                                                                                                                                                                                                                                     'low': 0,
#                                                                                                                                                                                                                                     'medium': 1}}}},
#                                                                                                                                                                                   1: 0}}}},
#                                                                                                                     'hr': {'salary': {'high': 0,
#                                                                                                                                       'low': 0,
#                                                                                                                                       'medium': 0}},
#                                                                                                                     'management': 0,
#                                                                                                                     'marketing': 0,
#                                                                                                                     'product_mng': 0,
#                                                                                                                     'sales': {'salary': {'high': 0,
#                                                                                                                                          'low': {'number_project': {'3~4.5': 0,
#                                                                                                                                                                     '4.5~7': {'Work_accident': {0: {'last_evaluation': {'0.41~0.83': {'time_spend_company': {'2~4.5': 0,
#                                                                                                                                                                                                                                                              '4.5~6': 0}},
#                                                                                                                                                                                                                         '0.83~1.0': {'last_evaluation': {'0.84~0.915': 0,
#                                                                                                                                                                                                                                                          '0.915~1.0': 0}}}},
#                                                                                                                                                                                                 1: 0}}}},
#                                                                                                                                          'medium': 0}},
#                                                                                                                     'support': {'number_project': {'3~5.5': 0,
#                                                                                                                                                    '5.5~6': {'salary': {'high': 0,
#                                                                                                                                                                         'low': {'Work_accident': {0: {'last_evaluation': {'0.51~0.83': {'time_spend_company': {'2.5~5': 1,
#                                                                                                                                                                                                                                                                '2~2.5': 1}},
#                                                                                                                                                                                                                           '0.83~0.88': 0}},
#                                                                                                                                                                                                   1: 0}},
#                                                                                                                                                                         'medium': 0}}}},
#                                                                                                                     'technical': {'last_evaluation': {'0.36~0.795': {'salary': {'high': 0,
#                                                                                                                                                                                 'low': 0,
#                                                                                                                                                                                 'medium': {'Work_accident': {0: {'time_spend_company': {'2~3.5': 0,
#                                                                                                                                                                                                                                         '3.5~8': {'number_project': {'3.5~6': 0,
#                                                                                                                                                                                                                                                                      '3~3.5': 0}}}},
#                                                                                                                                                                                                              1: 0}}}},
#                                                                                                                                                       '0.795~1.0': {'Work_accident': {0: {'last_evaluation': {'0.885~1.0': {'salary': {'high': 0,
#                                                                                                                                                                                                                                        'low': 0,
#                                                                                                                                                                                                                                        'medium': 0}},
#                                                                                                                                                                                                               '0.8~0.885': {'time_spend_company': {'2~4.0': 1,
#                                                                                                                                                                                                                                                    '4.0~6': {'time_spend_company': {'5.5~6': {'salary': {'high': 0,
#                                                                                                                                                                                                                                                                                                          'low': 0,
#                                                                                                                                                                                                                                                                                                          'medium': 0}},
#                                                                                                                                                                                                                                                                                     '5~5.5': {'salary': {'high': 0,
#                                                                                                                                                                                                                                                                                                          'low': 0,
#                                                                                                                                                                                                                                                                                                          'medium': 0}}}}}}}},
#                                                                                                                                                                                       1: 0}}}}}}}},
#                                                           '2~2.5': {'last_evaluation': {'0.37~0.575': 1,
#                                                                                         '0.575~1.0': 0}}}},
#                         '0.465~1.0': {'time_spend_company': {'2~4.5': 0,
#                                                              '4.5~10': {'last_evaluation': {'0.36~0.805': 0,
#                                                                                             '0.805~1.0': {'average_montly_hours': {'216.5~307': {'satisfaction_level': {'0.48~0.715': {'salary': {'high': 0,
#                                                                                                                                                                                                   'low': {'last_evaluation': {'0.81~0.905': {'sales': {'IT': 0,
#                                                                                                                                                                                                                                                        'RandD': 0,
#                                                                                                                                                                                                                                                        'accounting': {'promotion_last_5years': {0: 0,
#                                                                                                                                                                                                                                                                                                 1: 0}},
#                                                                                                                                                                                                                                                        'hr': 0,
#                                                                                                                                                                                                                                                        'management': 0,
#                                                                                                                                                                                                                                                        'marketing': 0,
#                                                                                                                                                                                                                                                        'product_mng': 0,
#                                                                                                                                                                                                                                                        'sales': 0,
#                                                                                                                                                                                                                                                        'support': 0,
#                                                                                                                                                                                                                                                        'technical': 0}},
#                                                                                                                                                                                                                               '0.905~1.0': {'sales': {'IT': 0,
#                                                                                                                                                                                                                                                       'RandD': 0,
#                                                                                                                                                                                                                                                       'accounting': 0,
#                                                                                                                                                                                                                                                       'hr': 0,
#                                                                                                                                                                                                                                                       'management': 0,
#                                                                                                                                                                                                                                                       'marketing': 0,
#                                                                                                                                                                                                                                                       'product_mng': 1,
#                                                                                                                                                                                                                                                       'sales': 1,
#                                                                                                                                                                                                                                                       'support': 0,
#                                                                                                                                                                                                                                                       'technical': 0}}}},
#                                                                                                                                                                                                   'medium': 0}},
#                                                                                                                                                                         '0.715~0.98': {'number_project': {'2~3.5': 0,
#                                                                                                                                                                                                           '3.5~6': 1}}}},
#                                                                                                                                    '98~216.5': {'time_spend_company': {'5.5~10': 0,
#                                                                                                                                                                        '5~5.5': {'salary': {'high': 0,
#                                                                                                                                                                                             'low': {'sales': {'IT': 0,
#                                                                                                                                                                                                               'RandD': 0,
#                                                                                                                                                                                                               'accounting': 0,
#                                                                                                                                                                                                               'hr': 1,
#                                                                                                                                                                                                               'management': 0,
#                                                                                                                                                                                                               'marketing': 0,
#                                                                                                                                                                                                               'product_mng': 0,
#                                                                                                                                                                                                               'sales': 1,
#                                                                                                                                                                                                               'support': {'satisfaction_level': {'0.53~0.62': 1,
#                                                                                                                                                                                                                                                  '0.62~0.79': 1}},
#                                                                                                                                                                                                               'technical': 0}},
#                                                                                                                                                                                             'medium': 0}}}}}}}}}}}}

# %%
def predict(inst,tree):
    for nodes in tree.keys():
        value = inst[nodes]
        #print value
        value = value.tolist()
        value = value[0]
        #print nodes
        if not is_categorical(nodes):
            found = False
            for Range_str in tree[nodes].keys():
                #print Range_str
                Range = Range_str.split('~')
                if value >= float(Range[0]) and value <= float(Range[1]):
                    value = Range_str
                    found = True
            
            if not found:
                Range_str = tree[nodes].keys()[0]
                if value < float(Range[0]):
                    value = Range_str
                
                Range_str = tree[nodes].keys()[len(tree[nodes].keys())-1]
                if value > float(Range[1]):
                    value = Range_str
                    
        #print nodes, value
        tree = tree[nodes][value]
        prediction = 0
            
        if type(tree) is dict:
            prediction = predict(inst, tree)
        else:
            prediction = tree
            break;                            
    
    return prediction


def calculate_performance(validation_data):
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    
    for i in range(len(validation_data.index)):
        row = validation_data.iloc[[i]][Y]
        row = row.tolist()
        row = row[0]
        if predict(validation_data.iloc[[i]], decision_tree) == 1:
            if row == 1:
                TP += 1
            else:
                FP += 1
        else:
            if row == 0:
                TN += 1
            else:
                FN += 1

    accuracy = float(TP + TN) / (TP + TN + FP + FN)
    
    if TP + FP == 0:
        precision = 0
    else:
        precision = float(TP) / (TP + FP)
        
    if TP + FN == 0:
        recall = 0
    else:
        recall = float(TP) / (TP + FN)
        
    F1measure = 2.0 / ( (1/recall) + (1/precision) )
        
    print ("accuracy =", accuracy)
    print ("precision =", precision)
    print ("recall =", recall)
    print ("F1 measure =", F1measure)
    print ((TP + TN + FP + FN), len(validation_data.index))
    print TP, TN, FP, FN

calculate_performance(validation_data)
# Out:
# ('accuracy =', 0.9621886120996441)
# ('precision =', 0.9307116104868914)
# ('recall =', 0.9119266055045872)
# ('F1 measure =', 0.9212233549582948)
# (2248, 2248)
# 497 1666 37 48

# %%
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()  
classifier.fit(pandas.get_dummies(data[X],drop_first=True), data[Y])

y_pred = classifier.predict(pandas.get_dummies(validation_data[X],drop_first=True))

from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(validation_data[Y], y_pred))  
print(classification_report(validation_data[Y], y_pred))

from sklearn.metrics import accuracy_score

print accuracy_score(validation_data[Y], y_pred)
